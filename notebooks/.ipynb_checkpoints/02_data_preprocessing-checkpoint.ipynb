# %% [markdown]
# ## Data Inspection
# - Plot EEG data
# - compute noise covariance
# - compute data covariance

# %%
# imports
import mne
import os

# data paths
data_path = "data"
subject_path = os.path.join("sub-024", "ses-mecha", "eeg")
epoch_file = "sub-024_ses-mecha_task-NT_epo.fif"
epochs_path = os.path.join(data_path, subject_path, epoch_file)

# %% [markdown]
# ### EEG Data
# We load and inspect data from one participant.

# %%
# load data
epochs = mne.read_epochs(epochs_path, preload=True)


# inspect EEG data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # load data
# ----> 2 epochs = mne.read_epochs(epochs_path, preload=True)
#       3
#       4
#       5 # inspect EEG data
#
# File <decorator-gen-234>:12, in read_epochs(fname, proj, preload, verbose)
#
# File /data/u_grossmannr_software/miniforge3/envs/sourcerec-tutorial/lib/python3.11/site-packages/mne/epochs.py:4245, in read_epochs(fname, proj, preload, verbose)
#    4227 @verbose
#    4228 def read_epochs(fname, proj=True, preload=True, verbose=None) -> "EpochsFIF":
#    4229     """Read epochs from a fif file.
#    4230
#    4231     Parameters
#    (...)   4243         The epochs.
#    4244     """
# -> 4245     return EpochsFIF(fname, proj, preload, verbose)
#
# File <decorator-gen-235>:12, in __init__(self, fname, proj, preload, verbose)
#
# ...

# %%
epochs.average()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 epochs.average
#
# NameError: name 'epochs' is not defined
